# %%
import zipfile
import os

# Path to your zip file
zip_path = '/content/ts pmo.zip'
# Path to extract the contents
extract_to = '/content/'

# Extract the zip
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print("Extraction complete.")
# Out:
# Extraction complete.

# %%
# !python /content/pmo/main.py
# Out:
# Running Player Re-ID Demo...
# Initializing Player Re-ID System...
# Using device: cpu
# Error loading YOLO model: PytorchStreamReader failed reading zip archive: invalid header or archive is corrupted
# Falling back to default YOLOv11n model...
# Two-stream ReID network loaded successfully
# System initialization complete!
# Processing video: 15sec_input_720p.mp4
# Processing frames:   0% 0/375 [00:00<?, ?it/s]requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 0.9s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# Error processing frame 0:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   0% 1/375 [00:02<13:29,  2.16s/it]Error processing frame 1:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   1% 2/375 [00:02<06:27,  1.04s/it]Error processing frame 2:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   1% 3/375 [00:02<04:03,  1.52it/s]Error processing frame 3:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   1% 4/375 [00:02<02:58,  2.08it/s]Error processing frame 4:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   1% 5/375 [00:03<02:22,  2.60it/s]Error processing frame 5:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   2% 6/375 [00:03<01:59,  3.08it/s]Error processing frame 6:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   2% 7/375 [00:03<01:45,  3.50it/s]Error processing frame 7:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   2% 8/375 [00:03<01:36,  3.80it/s]Error processing frame 8:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   2% 9/375 [00:03<01:23,  4.38it/s]Error processing frame 9:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   3% 10/375 [00:03<01:13,  4.99it/s]Error processing frame 10:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   3% 11/375 [00:04<01:05,  5.52it/s]Error processing frame 11:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   3% 12/375 [00:04<01:01,  5.93it/s]Error processing frame 12:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   3% 13/375 [00:04<00:56,  6.36it/s]Error processing frame 13:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   4% 14/375 [00:04<00:53,  6.70it/s]Error processing frame 14:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   4% 15/375 [00:04<00:53,  6.76it/s]Error processing frame 15:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   4% 16/375 [00:04<00:51,  7.02it/s]Error processing frame 16:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   5% 17/375 [00:04<00:50,  7.13it/s]Error processing frame 17:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   5% 18/375 [00:05<00:49,  7.27it/s]Error processing frame 18:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   5% 19/375 [00:05<00:47,  7.43it/s]Error processing frame 19:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   5% 20/375 [00:05<00:48,  7.28it/s]Error processing frame 20:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   6% 21/375 [00:05<00:48,  7.37it/s]Error processing frame 21:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   6% 22/375 [00:05<00:47,  7.36it/s]Error processing frame 22:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   6% 23/375 [00:05<00:48,  7.24it/s]Error processing frame 23:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   6% 24/375 [00:05<00:47,  7.33it/s]Error processing frame 24:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   7% 25/375 [00:05<00:47,  7.39it/s]Error processing frame 25:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   7% 26/375 [00:06<00:46,  7.46it/s]Error processing frame 26:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   7% 27/375 [00:06<00:46,  7.52it/s]Error processing frame 27:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   7% 28/375 [00:06<00:45,  7.58it/s]Error processing frame 28:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   8% 29/375 [00:06<00:45,  7.54it/s]Error processing frame 29:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   8% 30/375 [00:06<00:46,  7.37it/s]Error processing frame 30:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   8% 31/375 [00:06<00:45,  7.54it/s]Error processing frame 31:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   9% 32/375 [00:06<00:45,  7.51it/s]Error processing frame 32:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   9% 33/375 [00:07<00:45,  7.52it/s]Error processing frame 33:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames:   9% 34/375 [00:07<00:45,  7.57it/s]Error processing frame 34:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#
# Processing frames
irements.txt
# Out:
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 4)) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 5)) (0.21.0+cu124)
# Requirement already satisfied: ultralytics>=8.0.196 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 6)) (8.3.160)
# Requirement already satisfied: opencv-python>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 7)) (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 12)) (4.11.0.86)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 13)) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->-r /content/requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->-r /content/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (1.15.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->-r /content/requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics>=8.0.196->-r /content/requirements.txt (line 6)) (1.17.0)

# %%
# !python test_setup.py
# Out:
# 🧪 Testing Transformer-Based Player Re-ID Setup
# ==================================================
# 🔍 Testing PyTorch...
# ✅ PyTorch 2.6.0+cu124 installed
# ⚠️  CUDA not available - will use CPU (slower)
#
# 🔍 Testing Ultralytics...
# ✅ Ultralytics imported successfully
# ✅ Found your fine-tuned model: best.pt
# ✅ Your fine-tuned model loads successfully
#
# 🔍 Testing OpenCV...
# ✅ OpenCV 4.11.0 installed
# ✅ Found your input video: 15sec_input_720p.mp4
# ✅ Video info: 1280x720, 25.0fps, 15.0s, 375 frames
# ✅ Video duration is approximately 15 seconds
#
# 🔍 Testing Transformer AutoEncoder...
# ✅ Positional encoding working
# ✅ Transformer AutoEncoder working
#    Input shape: torch.Size([8, 1, 256])
#    Latent shape: torch.Size([1, 512])
#    Output dim: 512 (128D as expected)
#
# 🔍 Testing memory requirements...
# ℹ️  Using CPU - memory usage will be in RAM instead of GPU
#
# 📊 Test Results: 5/5 passed
#
# 🎉 All tests passed! You're ready to process your 15-second clip.
# Run: python run_15sec_clip.py

# %%
# !python run_15sec_clip.py
# Out:
# 🏃‍♂️ Transformer-Based Player Re-Identification for 15-Second Clips
# ============================================================
# ✅ PyTorch 2.6.0+cu124 - Ready
# ✅ Device: CPU
#
# Checking required files...
# ✅ best.pt - Found
# ✅ 15sec_input_720p.mp4 - Found
#
# Configuration:
# 📦 Model: best.pt
# 🎬 Input: 15sec_input_720p.mp4
# 💾 Output: output_transformer_reid.mp4
#
# 🚀 Initializing Transformer-based tracker...
# Loading your fine-tuned model: best.pt
# ✅ Tracker initialized successfully
#
# 🎯 Processing your 15-second clip...
# This will:
# • Detect players using your fine-tuned YOLOv11 model
# • Track them with Transformer-based temporal features
# • Maintain consistent IDs when players exit/re-enter
# • Save annotated video with persistent player IDs
# Processing 15-second clip: 15sec_input_720p.mp4
# Video specs: 1280x720 @ 25.0fps
# Processed 30/375 frames
# Processed 60/375 frames
# Processed 90/375 frames
# Processed 120/375 frames
# Processed 150/375 frames
# Processed 180/375 frames
# Processed 210/375 frames
# Processed 240/375 frames
# Processed 270/375 frames
# Processed 300/375 frames
# Processed 330/375 frames
# Processed 360/375 frames
# ✅ Completed! Output saved: output_transformer_reid.mp4
# Total unique players identified: 1125
# Total frames processed: 375
#
# 🎉 SUCCESS!
# ✅ Processed video saved: output_transformer_reid.mp4
# ✅ Players maintain consistent IDs throughout the clip
# ✅ Transformer features help with re-identification after exits
#
# 📊 Statistics:
# • Unique players identified: 1125
# • Total frames processed: 375
# • Using sequence length: 8 frames
